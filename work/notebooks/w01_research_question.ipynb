# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
"""Lane : Refresh / Content Opportunity Scoring.
Why I selected: I selected this lane because it focuses on identifying webpages that are likely declining and ranking them based on refresh priority.
This directly supports content optimization decisions using search performance data."""
# Out:
# 'Lane : Refresh / Content Opportunity Scoring.\nWhy I selected: I selected this lane because it focuses on identifying webpages that are likely declining and ranking them based on refresh priority.\nThis directly supports content optimization decisions using search performance data.'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
""" My Work helps decide which webpages should be prioritized for content refresh based on their search performance and predicted likelihood of decline.
The SEO team, content writers, or content managers use the ranked recommendations to decide which pages to update first.
A wrong recommendation can waste time and resources by prioritizing pages that do not need updates, while pages that are actually declining may be ignored, leading to continued traffic loss and missed growth opportunities."""
# Out:
# ' My Work helps decide which webpages should be prioritized for content refresh based on their search performance and predicted likelihood of decline.\nThe SEO team, content writers, or content managers use the ranked recommendations to decide which pages to update first.\nA wrong recommendation can waste time and resources by prioritizing pages that do not need updates, while pages that are actually declining may be ignored, leading to continued traffic loss and missed growth opportunities.'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import sys
import subprocess

REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/flyrank-ml-internship-starter

# %%
# !pip install reportlab
# !python scripts/run_all.py
import pandas as pd
import json
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df.head()
print("Total pages:", len(df))
corr = df["search_volume"].corr(df["impressions_90d"])
print("Correlation between search_volume and impressions_90d:", round(corr, 3))

with open("outputs/model_results.json", "r") as f:
    results = json.load(f)

baseline = results["baseline"]["baseline_precision_at_50"]
rf = results["models"]["random_forest"]["precision_at_50"]

print("Baseline Precision@50:", baseline)
print("Random Forest Precision@50:", rf)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.7 MB/s eta 0:00:00
# ...
#
# ...
# ▶ Step 1/5 — Prepare features — clean the data, build the feature vector, define the label
# ...
# Prepared 30,000 rows from 30,000 raw rows
# Wrote /content/flyrank-ml-internship-starter/data/processed/refresh_feature_vector.csv
#
# ...
# ▶ Step 2/5 — Baseline — a transparent hand-written rule to beat
# ...
# Wrote baseline queue: /content/flyrank-ml-internship-starter/data/processed/baseline_refresh_queue.csv
# Top-50 declining rate (full data, not the evaluated holdout Precision@50): 0.340
#
# ...
# ▶ Step 3/5 — Train — logistic regression, decision tree, random forest (client-holdout split)
# ...
# Trained 3 models on 30,000 rows
# Split strategy: client_holdout
# Best model: random_forest
# Wrote predictions: /content/flyrank-ml-internship-starter/data/processed/model_predictions.csv
# Wrote model results: /content/flyrank-ml-internship-starter/outputs/model_results.json
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
"""The model identifies observed patterns in the available search data.
It provides directional insights about which webpages are more likely to need a content refresh.
It supports decision-making by ranking webpages based on their predicted refresh priority.
The recommendations are intended to help SEO and content teams prioritize their work more effectively."""
# Out:
# 'The model identifies observed patterns in the available search data.\nIt provides directional insights about which webpages are more likely to need a content refresh.\nIt supports decision-making by ranking webpages based on their predicted refresh priority.\nThe recommendations are intended to help SEO and content teams prioritize their work more effectively.'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
