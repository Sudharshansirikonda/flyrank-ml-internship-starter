# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git

import os
os.chdir("flyrank-ml-internship-starter")

print(os.getcwd())
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 283 (delta 106), reused 78 (delta 78), pack-reused 147 (from 1)
# Receiving objects: 100% (283/283), 1.85 MiB | 12.83 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# /content/flyrank-ml-internship-starter

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
'''Lane: Refresh / Content Opportunity Scoring

   ML Task Type: Binary Classification with Ranking

   The model first predicts whether a webpage is likely to be declining (classification).
   It then assigns a score to each page and ranks them so the highest-priority pages can be reviewed first.'''
# Out:
# 'Lane: Refresh / Content Opportunity Scoring\n\n   ML Task Type: Binary Classification with Ranking\n\n   The model first predicts whether a webpage is likely to be declining (classification).\n   It then assigns a score to each page and ranks them so the highest-priority pages can be reviewed first.'

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
''' The Target Variable is is_delicining_label , which is derived from trend_direction column.
    if trend_direction==down:
        is_delicining_label=1
    else:
        is_delicining_label=0

    the target indicates whether a webpage should be considered for content refresh'''
# Out:
# ' The Target Variable is is_delicining_label , which is derived from trend_direction column.\n    if trend_direction==down:\n        is_delicining_label=1\n    else:\n        is_delicining_label=0\n\n    the target indicates whether a webpage should be considered for content refresh'

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
''' The primary Evaluation metric is Precision@50.
    Precision@50 measures how many of the top 50 recommended pages are actually declining.
    This metric is suitable because the business only reviews a limited number of pages,
    so the quality of the highest-ranked recommendations is more important than overall accuracy.'''
# Out:
# ' The primary Evaluation metric is Precision@50.\n    Precision@50 measures how many of the top 50 recommended pages are actually declining.\n    This metric is suitable because the business only reviews a limited number of pages,\n    so the quality of the highest-ranked recommendations is more important than overall accuracy.'

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.iloc[[0]]
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 0         4.55             0.0             good       striking
#
#    trend_direction  trend_pct
# 0             down      -41.4
#
# [1 rows x 44 columns]

# %%
'''Unit of Analysis

Each row in the dataset represents **one webpage**.

Each webpage contains search performance metrics such as impressions, click-through rate, search volume, content age, and ranking information.

The model makes one prediction for each webpage.'''
# Out:
# 'Unit of Analysis\n\nEach row in the dataset represents **one webpage**.\n\nEach webpage contains search performance metrics such as impressions, click-through rate, search volume, content age, and ranking information.\n\nThe model makes one prediction for each webpage.'

# %%
df[["trend_direction"]].head(10)
# Out:
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down
# 5            down
# 6            down
# 7          stable
# 8            down
# 9            down

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Create the target label
df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)

# Show it
df[["trend_direction", "is_declining_label"]].head(10)
# Out:
#   trend_direction  is_declining_label
# 0            down                   1
# 1            down                   1
# 2            down                   1
# 3          stable                   0
# 4            down                   1
# 5            down                   1
# 6            down                   1
# 7          stable                   0
# 8            down                   1
# 9            down                   1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
## Why ML Beats a Fixed Rule

'''A fixed rule relies on one or two manually selected conditions, such as low CTR or declining impressions. However,
webpage performance depends on multiple interacting factors, including search position,
impressions, click-through rate, content age, and search volume.

A machine learning model can learn complex relationships among these features and produce more accurate rankings than a simple rule-based system.
This is supported by the starter pipeline, where the Random Forest model achieved a much higher Precision@50 than the baseline rule.'''
# Out:
# 'A fixed rule relies on one or two manually selected conditions, such as low CTR or declining impressions. However,\nwebpage performance depends on multiple interacting factors, including search position,\nimpressions, click-through rate, content age, and search volume.\n\nA machine learning model can learn complex relationships among these features and produce more accurate rankings than a simple rule-based system.\nThis is supported by the starter pipeline, where the Random Forest model achieved a much higher Precision@50 than the baseline rule.'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %%
## Self Check
'''
✅ My ML task type is clearly defined.

✅ The target variable is identified.

✅ The success metric matches the business goal.

✅ One row represents one webpage.

✅ The output supports a real business decision.

✅ Machine learning is justified instead of a fixed rule.'''
# Out:
# '\n✅ My ML task type is clearly defined.\n\n✅ The target variable is identified.\n\n✅ The success metric matches the business goal.\n\n✅ One row represents one webpage.\n\n✅ The output supports a real business decision.\n\n✅ Machine learning is justified instead of a fixed rule.'
